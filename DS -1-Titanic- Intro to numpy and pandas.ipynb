# %%
import numpy as np

# %%
import pandas as pd

# %%
array =np.array([10,20,30,40,50])

# %%
print("NumPy Array:")
print(array)
# Out:
# NumPy Array:
# [10 20 30 40 50]

# %%
print("Shape of Array:", array.shape)
# Out:
# Shape of Array: (5,)

# %%
#Pandas

# %%
series = pd.Series([10,20,30,40,50])

# %%
print("Pandas Series:")
# Out:
# Pandas Series:

# %%
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#Create a Pandas DataFrame with at least 3 columns and 5 rows.

# %%
data = {
    "Name": ["Arun", "Bala", "Chitra", "Divya", "Esha"],
    "Age": [20, 21, 19, 22, 20],
    "Marks": [85, 78, 92, 88, 76]
}

df = pd.DataFrame(data)

print("DataFrame:")
print(df)
# Out:
# DataFrame:
#      Name  Age  Marks
# 0    Arun   20     85
# 1    Bala   21     78
# 2  Chitra   19     92
# 3   Divya   22     88
# 4    Esha   20     76

# %%
# Import a CSV file into a DataFrame using pd.read_csv()

# %%
csv_df = pd.read_csv("C:/Users/Shree Varsha/Downloads/student_performance.csv")

print("CSV Data:")
print(csv_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 csv_df = pd.read_csv("C:/Users/Shree Varsha/Downloads/student_performance.csv")
#       3 print("CSV Data:")
#       4 print(csv_df)
#
# ...

# %%
#Import an Excel file into a DataFrame using pd.read_excel()

# %%
excel_df = pd.read_excel("C:/Users/Shree Varsha/Downloads/Student_Performance_MLP_Dataset_100.xlsx")

print("Excel Data:")
print(excel_df)

# %%
#Display the first 5 rows of the imported DataFrame using df.head().

# %%
print("First 5 Rows:")
print(csv_df.head())

# %%
#Check the size of the DataFrame using df.size.

# %%
print("\nSize of DataFrame:")
print(csv_df.size)
# Out:
# Size of DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 print("\nSize of DataFrame:")
# ----> 2 print(csv_df.size)
#
# NameError: name 'csv_df' is not defined

# %%
#Check the shape of the DataFrame using df.shape

# %%
print("\nShape of DataFrame:")
print(csv_df.shape)
# Out:
# Shape of DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 print("\nShape of DataFrame:")
# ----> 2 print(csv_df.shape)
#
# NameError: name 'csv_df' is not defined

# %%
#Display the column names using df.columns.

# %%
print("\nColumn Names:")
print(csv_df.columns)
# Out:
# Column Names:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 print("\nColumn Names:")
# ----> 2 print(csv_df.columns)
#
# NameError: name 'csv_df' is not defined

# %%
#Use df.info() to view data types, non-null values, and memory usage

# %%
print("\nDataFrame Information:")
csv_df.info()
# Out:
# DataFrame Information:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 print("\nDataFrame Information:")
# ----> 2 csv_df.info()
#
# NameError: name 'csv_df' is not defined
